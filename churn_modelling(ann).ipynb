# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Churn_Modelling.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
x=df.iloc[:,3:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
x['Geography'].replace({'France':0,'Germany':1,'Spain':2},inplace=True)

# %%
x['Gender'].replace({'Female':0,'Male':1},inplace=True)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from  sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
x
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential  # it is used to initialize ann
from tensorflow.keras.layers import Dense # provides layer

# %%
ann=Sequential() # step1 initialize the ann

ann.add(Dense(units=6,activation='relu'))  # step2 add hidden layer

ann.add(Dense(units=1,activation='sigmoid')) # step add output layer

ann.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy']) #establishing connection

ann.fit(xtrain,ytrain,batch_size=30,epochs=50) #train the model

ypred=ann.predict(xtest)# make prediction
# Out:
# Epoch 1/50
# 234/234 [==============================] - 2s 3ms/step - loss: 0.5918 - accuracy: 0.7720
# Epoch 2/50
# 234/234 [==============================] - 1s 3ms/step - loss: 0.5095 - accuracy: 0.7987
# Epoch 3/50
# 234/234 [==============================] - 1s 3ms/step - loss: 0.4653 - accuracy: 0.8051
# Epoch 4/50
# 234/234 [==============================] - 1s 3ms/step - loss: 0.4412 - accuracy: 0.8114
# Epoch 5/50
# 234/234 [==============================] - 1s 2ms/step - loss: 0.4288 - accuracy: 0.8139
# Epoch 6/50
# 234/234 [==============================] - 0s 2ms/step - loss: 0.4214 - accuracy: 0.8146
# Epoch 7/50
# 234/234 [==============================] - 0s 2ms/step - loss: 0.4157 - accuracy: 0.8174
# Epoch 8/50
# 234/234 [==============================] - 1s 2ms/step - loss: 0.4110 - accuracy: 0.8190
# Epoch 9/50
# 234/234 [==============================] - 0s 2ms/step - loss: 0.4071 - accuracy: 0.8203
# Epoch 10/50
# ...

# %%
ypred=ypred>0.5

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      2373
#            1       0.77      0.39      0.52       627
#
#     accuracy                           0.85      3000
#    macro avg       0.81      0.68      0.71      3000
# weighted avg       0.84      0.85      0.83      3000
